# %% [markdown]
# Write a Python program to remove duplicates from a list.
#
# ![image.png](attachment:image.png)

# %%
a = [-12, 20, -27, 20, 45, -12, 60]

dup_items = set()
uniq_items = []

for x in a:
    if x not in dup_items:
        uniq_items.append(x)
        
        dup_items.add(x)
        
print(dup_items)
# Out:
# {-27, 45, -12, 20, 60}
