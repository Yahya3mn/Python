# %% [markdown]
# Write a Python program to get the largest number from a list.
#
# ![image.png](attachment:image.png)

# %%
def max_num_in_list(list):
    
    max = list[0]
    
    for n in list:
        
        if n > max:
            
            max = n
            
    return max

print(max_num_in_list([8,-5,22,-3]))
# Out:
# 22
