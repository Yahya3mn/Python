# %% [markdown]
# Write a Python program to reverse a tuple.
#
# ![image.png](attachment:image.png)

# %%
x = ("w3resource")

y = reversed(x)
print(tuple(y))
# Out:
# ('e', 'c', 'r', 'u', 'o', 's', 'e', 'r', '3', 'w')

# %%
x = (5,10,15,20)

y = reversed(x)
print(tuple(y))
# Out:
# (20, 15, 10, 5)
