# %% [markdown]
# # Write a Python program to check if a set is a subset of another set.
#
# From Wikipedia,
# In mathematics, a set A is a subset of a set B if all elements of A are also elements of B; B is then a superset of A. It is possible for A and B to be equal; if they are unequal, then A is a proper subset of B. The relationship of one set being a subset of another is called inclusion (or sometimes containment). A is a subset of B may also be expressed as B includes (or contains) A or A is included (or contained) in B.
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)

# %%
sx = set(["Mango", "Apple"])
sy = set(["Mango", "Orange"])
sz = set(["Mango"])

print("x : ", sx)
print("y : ", sy)
print("z : ", sz)

print("\nIf x is a subset of y")
print(sx <= sy)
print(sx.issubset(sy))


print("\nIf y is a subset of x")
print(sy <= sx)
print(sy.issubset(sx))


print("\nIf x is a subset of z")
print(sx <= sz)
print(sx.issubset(sz))

print("\nIf y is a subset of z")
print(sy <= sz)
print(sy.issubset(sz))

print("\nIf z is a subset of y")
print(sz <= sy)
print(sz.issubset(sy))
# Out:
# x :  {'Apple', 'Mango'}
# y :  {'Orange', 'Mango'}
# z :  {'Mango'}
#
# If x is a subset of y
# False
# False
#
# If y is a subset of x
# False
# False
#
# If x is a subset of z
# False
# False
#
# If y is a subset of z
# False
# False
#
# If z is a subset of y
# True
# True
